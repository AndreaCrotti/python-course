# %%
import seaborn
import ggplot
import bokeh
import numpy as np
from matplotlib import pyplot
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
# %matplotlib inline

# %%
from bokeh import charts
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="57e1e82c-aca5-4e7d-aabd-77e3117c388b">Loading BokehJS ...</span>
#     </div>

# %%
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100

radii = np.random.random(size=N) * 1.5

# %%
p = figure()
p.circle(x, y, radius=radii)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1329c426-2ddc-4d27-a9c9-371dee25791e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1329c426-2ddc-4d27-a9c9-371dee25791e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1329c426-2ddc-4d27-a9c9-371dee25791e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9aa97729-d37e-417b-880b-a71b1fcce9d5":{"roots":{"references":[{"attributes":{},"id":"47778a07-1d66-48a6-94e1-a2e378788e13","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4609f9ff-cc8f-4864-9d67-4b684b51b902","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"744fba5e-f34a-4c99-aa7f-e3e1c6562c8f","subtype":"Figure","type":"Plot"}},"id":"1a8e1a0f-f3c8-4a8e-8a68-e46dd6a82f1f","type":"HelpTool"},{"attributes":{},"id":"97b3fb44-0547-4f2b-bfea-6032a835cd5b","type":"BasicTicker"},{"attributes":{"plot":null,"text":null},"id":"38ff30fa-1318-453b-a206-1e9885314ec8","type":"Title"},{"attributes":{"plot":{"id":"744fba5e-f34a-4c99-aa7f-e3e1c6562c8f","subtype":"Figure","type":"Plot"}},"id":"9bbd6940-24e6-4ae9-b7dd-23dfae5fdcec","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"85f0eab6-c29e-4d7b-a9f8-22a805e9a47f","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e7b70e5-ad0a-4202-bd65-b107ac6d0bb7","type":"Circle"},{"attributes":{"formatter":{"id":"47778a07-1d66-48a6-94e1-a2e378788e13","type":"BasicTickFormatter"},"plot":{"id":"744fba5e-f34a-4c99-aa7f-e3e1c6562c8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"614d6bac-0b8a-4220-b6c9-96770250fdb7","type":"BasicTicker"}},"id":"66c3926a-7845-44f0-b459-c367d2c672c1","type":"LinearAxis"},{"attributes":{"plot":{"id":"744fba5e-f34a-4c99-aa7f-e3e1c6562c8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"97b3fb44-0547-4f2b-bfea-6032a835cd5b","type":"BasicTicker"}},"id":"2e5506ab-6c3f-4d72-bfbc-b62753a28e0d","type":"Grid"},{"attributes":{"formatter":{"id":"858dbe9f-843e-4cb8-879c-63e826e5a606","type":"BasicTickFormatter"},"plot":{"id":"744fba5e-f34a-4c99-aa7f-e3e1c6562c8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"97b3fb44-0547-4f2b-bfea-6032a835cd5b","type":"BasicTicker"}},"id":"a622485a-3ad2-4a20-8782-3b365f13bc21","type":"LinearAxis"},{"attributes":{},"id":"614d6bac-0b8a-4220-b6c9-96770250fdb7","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","radius","x"],"data":{"radius":[0.6330347501293456,0.7988113403830777,0.43988704214921615,0.9846823696054481,1.330098582097118,0.47539851980795583,0.03781221149983899,0.3164396172646628,1.2771623431041066,0.19207105728810453,0.5339821355788366,0.13711150277528633,0.4916692887656707,1.0983593873764943,1.1555303269526005,0.5838095131926881,1.4241754339910653,0.87475329350715,1.4702362338917583,1.4963457684974935,0.29615141805701684,1.1379927949341417,0.9088503112380266,0.4664054597946465,0.9214738696803342,1.3046238612448264,0.6455049296880027,0.6426413457202913,1.372991806073882,1.3130390302125876,1.2971798618536188,0.8273600799064796,1.2980547659455655,0.8029871546337202,1.4429591721688466,1.1243789939420905,0.2330871106678835,0.25723145253169877,0.7349320891795882,0.7336324997166347,0.947265841702928,0.16665586869992466,0.551056804083407,0.933259845326394,1.0409253662103697,1.4942443302921762,1.4041994217144798,0.06208977992836234,1.0013248597325837,0.1829972884316245,1.4166494973241448,0.7471543479907163,0.13452997047535947,0.1332848803860806,0.8560671669894276,0.6220378143128401,1.1410805796038184,1.0068334707559485,1.4408323030517418,1.1788284838745107,0.7862678598091086,0.28289612132659586,1.3405524685936285,0.3282436172031654,0.061455519366858447,1.1010163338789232,1.138063686418857,0.2905448415130372,1.0071491032337179,0.08252125110915248,0.0676274329734344 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[13]</strong>&gt;</code></p>

# %%
from ipywidgets import interact

# %%
x = np.linspace(0, 100 * np.pi, 20000)
y = np.sin(x)

# %%
pyplot.plot(x, y)

# %%
# Out:
# array([  0.        ,   0.3877551 ,   0.7755102 ,   1.16326531,
#          1.55102041,   1.93877551,   2.32653061,   2.71428571,
#          3.10204082,   3.48979592,   3.87755102,   4.26530612,
#          4.65306122,   5.04081633,   5.42857143,   5.81632653,
#          6.20408163,   6.59183673,   6.97959184,   7.36734694,
#          7.75510204,   8.14285714,   8.53061224,   8.91836735,
#          9.30612245,   9.69387755,  10.08163265,  10.46938776,
#         10.85714286,  11.24489796,  11.63265306,  12.02040816,
#         12.40816327,  12.79591837,  13.18367347,  13.57142857,
#         13.95918367,  14.34693878,  14.73469388,  15.12244898,
#         15.51020408,  15.89795918,  16.28571429,  16.67346939,
#         17.06122449,  17.44897959,  17.83673469,  18.2244898 ,
#         18.6122449 ,  19.        ])
