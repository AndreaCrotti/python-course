# %%
import geopandas
import matplotlib
# %matplotlib inline

# %%
df = geopandas.gpd.read_file("maps/countries.dbf")

# %%
df
# Out:
#          CONTINENT                               COUNTRY  \
# 0           Europe                                 Åland
# 1             Asia                           Afghanistan
# 2           Europe                               Albania
# 3           Africa                               Algeria
# 4          Oceania                        American Samoa
# 5           Europe                               Andorra
# 6           Africa                                Angola
# 7    North America                              Anguilla
# 8        Antartica                            Antarctica
# 9    North America                   Antigua and Barbuda
# 10   South America                             Argentina
# 11            Asia                               Armenia
# 12   South America                                 Aruba
# 13         Oceania                             Australia
# 14         Oceania                             Australia
# ...

# %%
geom_italy = df[df.COUNTRY == "Italy"].geometry

# %%
geom_italy.plot()
